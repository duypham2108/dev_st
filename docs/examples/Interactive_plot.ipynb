# %% [markdown]
# # Interactive plots

# %% [markdown]
# In this tutorial, we introduce several functions for interactive plot to explore the progression of Ductal Carcinoma in situ (DCIS) - Invasive Ductal Cancer (IDC)
#
# Source: https://support.10xgenomics.com/spatial-gene-expression/datasets
#
# If you are using jupyter lab, then you need to run these two lines of code:
#
# ```
# jupyter labextension install @jupyter-widgets/jupyterlab-manager
# jupyter labextension install @bokeh/jupyter_bokeh
# ```

# %%
import stlearn as st

# %%
data = st.dataset.example_bcba()

# %%
data
# Out:
# AnnData object with n_obs × n_vars = 3813 × 2
#     obs: 'in_tissue', 'array_row', 'array_col', 'imagecol', 'imagerow', 'louvain', 'dpt_pseudotime', 'sub_cluster_labels'
#     var: 'gene_ids', 'n_cells', 'mean', 'std'
#     uns: 'PTS_graph', 'centroid_dict', 'clade_12', 'clade_6', 'diffmap_evals', 'global_graph', 'iroot', 'louvain', 'louvain_colors', 'louvain_sizes', 'lr', 'neighbors', 'paga', 'pca', 'screening_result_global', 'selected', 'spatial', 'split_node', 'threshold_spots'
#     obsm: 'cci_lr', 'lr', 'lr_pvalues', 'lr_sign', 'spatial'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
st.pl.gene_plot_interactive

# %% [markdown]
# <img src="../_static/img/bokeh/gene_plot.png">

# %%
st.pl.cluster_plot_interactive(data,use_label="louvain")
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1101">Loading BokehJS ...</span>
#     </div>
# <script id="1102">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:55160/autoload.js?bokeh-autoload-element=1102&bokeh-absolute-url=http://localhost:55160&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>
# ERROR:bokeh.server.protocol_handler:error handling message
#  message: Message 'PATCH-DOC' content: {'events': [{'kind': 'ModelChanged', 'model': {'id': '1005'}, 'attr': 'active', 'new': [0]}], 'references': []}
#  error: NetworkXError('The node 9999 is not in the graph.')
# Traceback (most recent call last):
# ...

# %%
st.pl.cluster_plot(data,use_label="louvain",show_trajectories=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda3\envs\stlearn\lib\site-packages\networkx\classes\graph.py in remove_node(self, n)
#     622         try:
# --> 623             nbrs = list(adj[n])  # list handles self-loops (allows mutation)
#     624             del self._node[n]
#
# KeyError: 9999
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-7-3c2def72599f> in <module>
# ----> 1 st.pl.cluster_plot(data,use_label="louvain",show_trajectories=True)
#
# ...
